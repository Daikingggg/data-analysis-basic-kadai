# %%
import matplotlib.pyplot as plt
import numpy as np

# データ生成
x = np.linspace(0, 10, 100)
y = 2 + 2 * np.sin(2 * x)


nrows, ncols = 2, 2
fig, axes = plt.subplots(nrows, ncols)
y0 = [1, 2, -5, 2]
axes[0,0].plot(y0)


axes[0, 0].plot(line_y)
axes[0, 0].set_title('Line Plot')

axes[0, 1].plot(x, y)
axes[0, 1].set_title('Sine Function')


axes[1, 0].hist(hist_data, bins=30, edgecolor='black')
axes[1, 0].set_title('Histogram')


axes[1, 1].scatter(scatter_x, scatter_y)
axes[1, 1].set_title('Scatter Plot')


axes[0, 0].set_xlim(0, 3)
axes[0, 0].set_xticks(np.arange(0, 4))
axes[0, 0].set_ylim(-6, 3)
axes[0, 0].set_yticks(np.arange(-6, 4))

axes[0, 1].set_xlim(0, 10)
axes[0, 1].set_xticks(np.arange(0, 11))
axes[0, 1].set_ylim(-1, 5)
axes[0, 1].set_yticks(np.arange(-1, 6))

plt.tight_layout()
plt.show()
